# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# NVIDIA GeForce RTX 3080 Ti, 12288 MiB, 12019 MiB

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/9db565e15e8e35f1ebb48e1409b8ddb129f6f1e9/examples/dreambooth/train_dreambooth.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. 
# Please, visit the [model card](https://huggingface.co/CompVis/stable-diffusion-v1-4), 
# read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, 
# and you'll also need to use an access token for the code to work.
# %pip install huggingface_hub
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"

from huggingface_hub import notebook_login
# !git config --global credential.helper store
notebook_login()
# Out:
# Requirement already satisfied: huggingface_hub in /home/alexander/.local/lib/python3.10/site-packages (0.11.1)
# Requirement already satisfied: requests in /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages (from huggingface_hub) (2.28.1)
# Requirement already satisfied: packaging>=20.9 in /home/alexander/.local/lib/python3.10/site-packages (from huggingface_hub) (22.0)
# Requirement already satisfied: filelock in /home/alexander/.local/lib/python3.10/site-packages (from huggingface_hub) (3.9.0)
# Requirement already satisfied: tqdm in /home/alexander/.local/lib/python3.10/site-packages (from huggingface_hub) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/alexander/.local/lib/python3.10/site-packages (from huggingface_hub) (4.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages (from requests->huggingface_hub) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages (from requests->huggingface_hub) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Install xformers from precompiled wheel.

# %%
# %pip install --no-deps -q https://github.com/brian6091/xformers-wheels/releases/download/0.0.15.dev0%2B4c06c79/xformers-0.0.15.dev0+4c06c79.d20221205-cp38-cp38-linux_x86_64.whl
# These were compiled on Tesla T4, should also work on P100, thanks to https://github.com/metrolobo

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers
# Out:
# ERROR: xformers-0.0.15.dev0+4c06c79.d20221205-cp38-cp38-linux_x86_64.whl is not a supported wheel on this platform.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Settings and run

# %%
#@markdown Name/Path of the initial model.
MODEL_NAME = "CompVis/stable-diffusion-v1-4" #@param {type:"string"}

#@markdown Path for images of the concept for training.
INSTANCE_DIR = "./data/frants" #@param {type:"string"}
# !mkdir -p $INSTANCE_DIR

#@markdown A general name for class like dog for dog images.
CLASS_NAME = "georgeclooney" #@param {type:"string"}
CLASS_DIR = f"./data/{CLASS_NAME}"

#@markdown A rare token name which will reference the subject.
TOKEN_NAME = "frants" #@param {type:"string"}

#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = False #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "frants" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "./models/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR

#@markdown sks is a rare identifier, feel free to replace it.
# Out:
# [*] Weights will be saved at ./data/weights/frants

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --instance_data_dir=$INSTANCE_DIR \
  --class_data_dir=$CLASS_DIR \
  --output_dir=$OUTPUT_DIR \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --instance_prompt="photo of {TOKEN_NAME} {CLASS_NAME}" \
  --class_prompt="photo of a {CLASS_NAME}" \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=200 \
  --sample_batch_size=4 \
  --max_train_steps=3200
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_cpu_threads_per_process` was set to `8` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100%|██████████████████████████████| 543/543 [00:00<00:00, 960kB/s]
# Fetching 16 files:   0%|                                 | 0/16 [00:00<?, ?it/s]
# Downloading: 100%|█████████████████████████████| 342/342 [00:00<00:00, 1.07MB/s]
# Fetching 16 files:   6%|█▌                       | 1/16 [00:01<00:18,  1.22s/it]
# Downloading: 100%|█████████████████████████| 4.56k/4.56k [00:00<00:00, 12.7MB/s]
# Fetching 16 files:  19%|████▋                    | 3/16 [00:02<00:09,  1.33it/s]
# Downloading:   0%|                                  | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|                          | 425k/1.22G [00:00<05:57, 3.40MB/s]
# Downloading:   0%|                         | 3.14M/1.22G [00:00<01:15, 16.1MB/s]
# Downloading:   1%|▏                        | 7.78M/1.22G [00:00<00:41, 29.1MB/s]
# Downloading:   1%|▎                        | 13.1M/1.22G [00:00<00:36, 32.8MB/s]
# Downloading:   2%|▍                        | 20.4M/1.22G [00:00<00:26, 45.6MB/s]
# Downloading:   2%|▌                        | 25.2M/1.22G [00:00<00:25, 46.5MB/s]
# Downloading:   3%|▋                        | 31.4M/1.22G [00:00<00:23, 51.0MB/s]
# Downloading:   3%|▊                        | 36.6M/1.22G [00:00<00:24, 47.3MB/s]
# Downloading:   4%|▉                        | 43.0M/1.22G [00:00<00:22, 52.2MB/s]
# Downloading:   4%|█                        | 50.2M/1.22G [00:01<00:20, 57.5MB/s]
# Downloading:   5%|█▏                       | 56.0M/1.22G [00:01<00:21, 54.5MB/s]
# Downloading:   5%|█▎                       | 62.9M/1.22G [00:01<00:19, 58.4MB/s]
# Downloading:   6%|█▍                       | 69.3M/1.22G [00:01<00:19, 60.2MB/s]
# Downloading:   6%|█▌                       | 75.9M/1.22G [00:01<00:18, 61.7MB/s]
# Downloading:   7%|█▋                       | 82.4M/1.22G [00:01<00:18, 62.8MB/s]
# Downloading:   7%|█▊                       | 89.6M/1.22G [00:01<00:17, 65.5MB/s]
# Downloading:   8%|█▉                       | 96.5M/1.22G [00:01<00:16, 66.3MB/s]
# Downloading:   8%|██▏                       | 103M/1.22G [00:01<00:17, 64.8MB/s]
# Downloading:   9%|██▎                       | 110M/1.22G [00:02<00:16, 66.4MB/s]
# Downloading:  10%|██▍                       | 117M/1.22G [00:02<00:17, 63.2MB/s]
# Downloading:  10%|██▋                       | 123M/1.22G [00:02<00:18, 58.9MB/s]
# Downloading:  11%|██▊                       | 129M/1.22G [00:02<00:20, 53.2MB/s]
# Downloading:  11%|██▉                       | 135M/1.22G [00:02<00:20, 52.8MB/s]
# Downloading:  12%|███                       | 141M/1.22G [00:02<00:19, 56.5MB/s]
# Downloading:  12%|███▏                      | 147M/1.22G [00:02<00:24, 43.3MB/s]
# Downloading:  12%|███▏                      | 152M/1.22G [00:02<00:25, 41.8MB/s]
# Downloading:  13%|███▎                      | 156M/1.22G [00:03<00:25, 40.9MB/s]
# Downloading:  13%|███▍                      | 161M/1.22G [00:03<00:27, 38.4MB/s]
# Downloading:  14%|███▌                      | 167M/1.22G [00:03<00:27, 37.6MB/s]
# Downloading:  14%|███▋                      | 171M/1.22G [00:03<00:26, 39.1MB/s]
# Downloading:  14%|███▋                      | 175M/1.22G [00:03<00:29, 35.4MB/s]
# Downloading:  15%|███▊                      | 181M/1.22G [00:03<00:25, 40.9MB/s]
# Downloading:  15%|███▉                      | 185M/1.22G [00:03<00:27, 38.0MB/s]
# Downloading:  16%|████                      | 189M/1.22G [00:03<00:27, 37.3MB/s]
# Downloading:  16%|████▏                     | 193M/1.22G [00:04<00:28, 35.6MB/s]
# Downloading:  16%|████▏                     | 197M/1.22G [00:04<00:27, 36.5MB/s]
# Downloading:  17%|████▎                     | 201M/1.22G [00:04<00:28, 35.9MB/s]
# Downloading:  98%|████████████████████████▍| 1.19G/1.22G [00:31<00:00, 35.3MB/s]
# Downloading:  98%|████████████████████████▍| 1.19G/1.22G [00:32<00:00, 35.2MB/s]
# Downloading:  98%|████████████████████████▌| 1.19G/1.22G [00:32<00:00, 35.0MB/s]
# Downloading:  98%|████████████████████████▌| 1.20G/1.22G [00:32<00:00, 34.7MB/s]
# Downloading:  99%|████████████████████████▋| 1.20G/1.22G [00:32<00:00, 35.2MB/s]
# Downloading:  99%|████████████████████████▊| 1.20G/1.22G [00:32<00:00, 35.5MB/s]
# Downloading:  99%|████████████████████████▊| 1.21G/1.22G [00:32<00:00, 36.3MB/s]
# Downloading: 100%|█████████████████████████| 1.22G/1.22G [00:32<00:00, 37.2MB/s]
# Fetching 16 files:  25%|██████▎                  | 4/16 [00:35<02:25, 12.09s/it]
# Downloading: 100%|██████████████████████████████| 209/209 [00:00<00:00, 487kB/s]
# Fetching 16 files:  31%|███████▊                 | 5/16 [00:37<01:33,  8.47s/it]
# Downloading: 100%|██████████████████████████████| 313/313 [00:00<00:00, 794kB/s]
# Fetching 16 files:  38%|█████████▍               | 6/16 [00:38<01:01,  6.13s/it]
# Downloading: 100%|█████████████████████████████| 592/592 [00:00<00:00, 1.76MB/s]
# Fetching 16 files:  44%|██████████▉              | 7/16 [00:39<00:41,  4.56s/it]
# Downloading:   0%|                                   | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|                           | 508k/492M [00:00<01:37, 5.05MB/s]
# Downloading:   1%|▏                         | 3.97M/492M [00:00<00:21, 22.3MB/s]
# Downloading:   2%|▍                         | 9.40M/492M [00:00<00:13, 36.9MB/s]
# Downloading:   3%|▋                         | 13.7M/492M [00:00<00:12, 39.1MB/s]
# Downloading:   4%|▉                         | 17.8M/492M [00:00<00:11, 39.9MB/s]
# Downloading:   5%|█▏                        | 23.2M/492M [00:00<00:11, 39.6MB/s]
# Downloading:   6%|█▌                        | 30.4M/492M [00:00<00:09, 49.1MB/s]
# Downloading:   7%|█▉                        | 36.6M/492M [00:00<00:08, 53.2MB/s]
# Downloading:   9%|██▎                       | 42.9M/492M [00:00<00:08, 56.0MB/s]
# Downloading:  10%|██▌                       | 48.6M/492M [00:01<00:08, 54.0MB/s]
# Downloading:  11%|██▉                       | 55.0M/492M [00:01<00:07, 56.7MB/s]
# Downloading:  12%|███▏                      | 60.7M/492M [00:01<00:07, 56.4MB/s]
# Downloading:  13%|███▌                      | 66.3M/492M [00:01<00:08, 51.2MB/s]
# Downloading:  15%|███▊                      | 72.2M/492M [00:01<00:07, 53.2MB/s]
# Downloading:  16%|████▏                     | 78.6M/492M [00:01<00:07, 56.2MB/s]
# Downloading:  17%|████▍                     | 85.1M/492M [00:01<00:06, 58.8MB/s]
# Downloading:  18%|████▊                     | 91.0M/492M [00:01<00:07, 55.4MB/s]
# Downloading:  20%|█████▏                    | 97.8M/492M [00:01<00:06, 58.8MB/s]
# Downloading:  21%|█████▋                     | 104M/492M [00:02<00:07, 49.0MB/s]
# Downloading:  22%|██████                     | 110M/492M [00:02<00:07, 53.3MB/s]
# Downloading:  88%|███████████████████████▊   | 434M/492M [00:10<00:01, 42.4MB/s]
# Downloading:  89%|████████████████████████   | 439M/492M [00:10<00:01, 43.7MB/s]
# Downloading:  90%|████████████████████████▎  | 443M/492M [00:11<00:01, 42.5MB/s]
# Downloading:  91%|████████████████████████▌  | 448M/492M [00:11<00:01, 38.2MB/s]
# Downloading:  92%|████████████████████████▊  | 452M/492M [00:11<00:01, 39.0MB/s]
# Downloading:  93%|█████████████████████████  | 456M/492M [00:11<00:00, 36.9MB/s]
# Downloading:  93%|█████████████████████████▏ | 460M/492M [00:11<00:00, 38.0MB/s]
# Downloading:  94%|█████████████████████████▍ | 464M/492M [00:11<00:00, 36.3MB/s]
# Downloading:  95%|█████████████████████████▋ | 468M/492M [00:11<00:00, 36.2MB/s]
# Downloading:  96%|█████████████████████████▊ | 472M/492M [00:11<00:00, 33.1MB/s]
# Downloading:  97%|██████████████████████████ | 475M/492M [00:11<00:00, 34.6MB/s]
# Downloading:  97%|██████████████████████████▎| 479M/492M [00:12<00:00, 34.9MB/s]
# Downloading:  98%|██████████████████████████▍| 483M/492M [00:12<00:00, 35.6MB/s]
# Downloading:  99%|██████████████████████████▋| 486M/492M [00:12<00:00, 34.7MB/s]
# Downloading: 100%|███████████████████████████| 492M/492M [00:12<00:00, 39.6MB/s]
# Fetching 16 files:  50%|████████████▌            | 8/16 [00:52<00:58,  7.25s/it]
# Downloading:   0%|                                   | 0.00/525k [00:00<?, ?B/s]
# Downloading:   1%|▏                         | 4.10k/525k [00:00<00:15, 32.7kB/s]
# Downloading:   6%|█▋                         | 32.8k/525k [00:00<00:03, 149kB/s]
# Downloading:  16%|████▏                      | 81.9k/525k [00:00<00:01, 262kB/s]
# Downloading:  34%|█████████▌                  | 180k/525k [00:00<00:00, 472kB/s]
# Downloading: 100%|████████████████████████████| 525k/525k [00:00<00:00, 839kB/s]
# Fetching 16 files:  56%|██████████████           | 9/16 [00:54<00:38,  5.56s/it]
# Downloading: 100%|█████████████████████████████| 472/472 [00:00<00:00, 1.47MB/s]
# Fetching 16 files:  62%|███████████████         | 10/16 [00:55<00:25,  4.22s/it]
# Downloading: 100%|█████████████████████████████| 806/806 [00:00<00:00, 2.10MB/s]
# Fetching 16 files:  69%|████████████████▌       | 11/16 [00:56<00:16,  3.29s/it]
# Downloading:   0%|                                  | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   3%|▊                         | 32.8k/1.06M [00:00<00:04, 249kB/s]
# Downloading:   8%|██                        | 81.9k/1.06M [00:00<00:03, 324kB/s]
# Downloading:  19%|█████                      | 197k/1.06M [00:00<00:01, 576kB/s]
# Downloading:  39%|██████████▍                | 410k/1.06M [00:00<00:00, 991kB/s]
# Downloading: 100%|█████████████████████████| 1.06M/1.06M [00:00<00:00, 1.60MB/s]
# Fetching 16 files:  75%|██████████████████      | 12/16 [00:58<00:11,  2.90s/it]
# Downloading: 100%|█████████████████████████████| 743/743 [00:00<00:00, 2.60MB/s]
# Fetching 16 files:  81%|███████████████████▌    | 13/16 [00:59<00:07,  2.37s/it]
# Downloading:   0%|                                  | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|                          | 540k/3.44G [00:00<10:39, 5.38MB/s]
# Downloading:   0%|                         | 4.17M/3.44G [00:00<02:26, 23.5MB/s]
# Downloading:   0%|                         | 10.4M/3.44G [00:00<01:23, 41.2MB/s]
# Downloading:   0%|                         | 15.8M/3.44G [00:00<01:14, 45.7MB/s]
# Downloading:   1%|▏                        | 21.3M/3.44G [00:00<01:09, 49.1MB/s]
# Downloading:   1%|▏                        | 27.7M/3.44G [00:00<01:03, 54.1MB/s]
# Downloading:   1%|▎                        | 34.4M/3.44G [00:00<00:58, 58.2MB/s]
# Downloading:   1%|▎                        | 40.2M/3.44G [00:00<00:58, 57.7MB/s]
# Downloading:   1%|▎                        | 46.0M/3.44G [00:00<01:02, 54.5MB/s]
# Downloading:   1%|▎                        | 51.5M/3.44G [00:01<01:01, 54.8MB/s]
# Downloading:   2%|▍                        | 58.9M/3.44G [00:01<00:55, 60.4MB/s]
# Downloading:   2%|▍                        | 65.4M/3.44G [00:01<00:54, 61.8MB/s]
# Downloading:   2%|▌                        | 71.6M/3.44G [00:01<00:56, 59.3MB/s]
# Downloading:   2%|▌                        | 78.8M/3.44G [00:01<00:53, 62.8MB/s]
# Downloading:   2%|▌                        | 85.1M/3.44G [00:01<00:53, 62.8MB/s]
# Downloading:   3%|▋                        | 91.5M/3.44G [00:01<00:53, 63.0MB/s]
# Downloading:   3%|▋                        | 98.2M/3.44G [00:01<00:51, 64.3MB/s]
# Downloading:   3%|▊                         | 105M/3.44G [00:01<00:50, 66.1MB/s]
# Downloading:   3%|▊                         | 112M/3.44G [00:01<00:49, 66.6MB/s]
# Downloading:   3%|▉                         | 119M/3.44G [00:02<00:49, 66.4MB/s]
# Downloading:   4%|▉                         | 125M/3.44G [00:02<00:52, 63.3MB/s]
# Downloading:   4%|▉                         | 132M/3.44G [00:02<01:03, 52.5MB/s]
# Downloading:   4%|█                         | 137M/3.44G [00:02<01:05, 50.1MB/s]
# Downloading:   4%|█                         | 143M/3.44G [00:02<01:17, 42.4MB/s]
# Downloading:   4%|█                         | 147M/3.44G [00:02<01:24, 38.7MB/s]
# Downloading:   4%|█▏                        | 152M/3.44G [00:02<01:21, 40.3MB/s]
# Downloading:   5%|█▏                        | 156M/3.44G [00:02<01:23, 39.4MB/s]
# Downloading:   5%|█▏                        | 160M/3.44G [00:03<01:27, 37.5MB/s]
# Downloading:   5%|█▏                        | 164M/3.44G [00:03<01:27, 37.5MB/s]
# Downloading:   5%|█▎                        | 168M/3.44G [00:03<01:27, 37.3MB/s]
# Downloading:   5%|█▎                        | 172M/3.44G [00:03<01:29, 36.4MB/s]
# Downloading:   5%|█▎                        | 175M/3.44G [00:03<01:33, 35.0MB/s]
# Downloading:   5%|█▎                        | 179M/3.44G [00:03<01:30, 35.9MB/s]
# Downloading:   5%|█▍                        | 183M/3.44G [00:03<01:33, 35.0MB/s]
# Downloading:   5%|█▍                        | 187M/3.44G [00:03<01:29, 36.2MB/s]
# Downloading:   6%|█▍                        | 190M/3.44G [00:03<01:28, 36.5MB/s]
# Downloading:   6%|█▍                        | 194M/3.44G [00:04<01:30, 35.8MB/s]
# Downloading:   6%|█▍                        | 198M/3.44G [00:04<01:30, 36.0MB/s]
# Downloading:   6%|█▌                        | 201M/3.44G [00:04<01:31, 35.3MB/s]
# Downloading:   6%|█▌                        | 205M/3.44G [00:04<01:30, 35.8MB/s]
# Downloading:   6%|█▌                        | 209M/3.44G [00:04<01:27, 36.7MB/s]
# Downloading:   6%|█▌                        | 213M/3.44G [00:04<01:24, 38.3MB/s]
# Downloading:   6%|█▋                        | 217M/3.44G [00:04<01:32, 34.9MB/s]
# Downloading:   6%|█▋                        | 221M/3.44G [00:04<01:35, 33.7MB/s]
# Downloading:   7%|█▋                        | 225M/3.44G [00:04<01:28, 36.3MB/s]
# Downloading:   7%|█▋                        | 229M/3.44G [00:05<01:30, 35.5MB/s]
# Downloading:   7%|█▊                        | 233M/3.44G [00:05<01:29, 35.8MB/s]
# Downloading:   7%|█▊                        | 237M/3.44G [00:05<01:38, 32.4MB/s]
# Downloading:   7%|█▊                        | 242M/3.44G [00:05<01:24, 38.0MB/s]
# Downloading:   7%|█▊                        | 246M/3.44G [00:05<01:36, 33.1MB/s]
# Downloading:   7%|█▉                        | 251M/3.44G [00:05<01:26, 36.8MB/s]
# Downloading:   7%|█▉                        | 255M/3.44G [00:05<01:21, 38.8MB/s]
# Downloading:   8%|█▉                        | 259M/3.44G [00:05<01:24, 37.7MB/s]
# Downloading:   8%|█▉                        | 263M/3.44G [00:05<01:27, 36.4MB/s]
# Downloading:   8%|██                        | 267M/3.44G [00:06<01:30, 34.9MB/s]
# Downloading:   8%|██                        | 271M/3.44G [00:06<01:31, 34.7MB/s]
# Downloading:   8%|██                        | 274M/3.44G [00:06<01:29, 35.3MB/s]
# Downloading:   8%|██                        | 278M/3.44G [00:06<01:29, 35.2MB/s]
# Downloading:   8%|██▏                       | 282M/3.44G [00:06<01:26, 36.5MB/s]
# Downloading:   8%|██▏                       | 286M/3.44G [00:06<01:35, 33.0MB/s]
# Downloading:   8%|██▏                       | 292M/3.44G [00:06<01:20, 39.2MB/s]
# Downloading:   9%|██▏                       | 296M/3.44G [00:06<01:37, 32.4MB/s]
# Downloading:   9%|██▎                       | 302M/3.44G [00:07<01:21, 38.7MB/s]
# Downloading:   9%|██▎                       | 306M/3.44G [00:07<01:27, 35.9MB/s]
# Downloading:   9%|██▎                       | 310M/3.44G [00:07<01:23, 37.3MB/s]
# Downloading:   9%|██▎                       | 314M/3.44G [00:07<01:31, 34.3MB/s]
# Downloading:   9%|██▍                       | 319M/3.44G [00:07<01:29, 35.0MB/s]
# Downloading:   9%|██▍                       | 323M/3.44G [00:07<01:27, 35.8MB/s]
# Downloading:  10%|██▍                       | 328M/3.44G [00:07<01:41, 30.7MB/s]
# Downloading:  10%|██▌                       | 334M/3.44G [00:07<01:23, 37.1MB/s]
# Downloading:  10%|██▌                       | 338M/3.44G [00:08<01:31, 33.8MB/s]
# Downloading:  10%|██▌                       | 343M/3.44G [00:08<01:21, 37.8MB/s]
# Downloading:  10%|██▌                       | 347M/3.44G [00:08<01:23, 37.2MB/s]
# Downloading:  99%|████████████████████████▊| 3.42G/3.44G [01:34<00:00, 38.2MB/s]
# Downloading: 100%|████████████████████████▉| 3.42G/3.44G [01:34<00:00, 38.8MB/s]
# Downloading: 100%|████████████████████████▉| 3.43G/3.44G [01:34<00:00, 35.5MB/s]
# Downloading: 100%|████████████████████████▉| 3.43G/3.44G [01:34<00:00, 37.0MB/s]
# Downloading: 100%|█████████████████████████| 3.44G/3.44G [01:34<00:00, 36.2MB/s]
# Fetching 16 files:  88%|█████████████████████   | 14/16 [02:35<01:00, 30.45s/it]
# Downloading: 100%|█████████████████████████████| 522/522 [00:00<00:00, 1.75MB/s]
# Fetching 16 files:  94%|██████████████████████▌ | 15/16 [02:36<00:21, 21.65s/it]
# Downloading:   0%|                                   | 0.00/335M [00:00<?, ?B/s]
# Downloading:   0%|                           | 294k/335M [00:00<01:55, 2.90MB/s]
# Downloading:   1%|▏                         | 2.49M/335M [00:00<00:23, 14.0MB/s]
# Downloading:   2%|▌                         | 6.93M/335M [00:00<00:11, 27.8MB/s]
# Downloading:   3%|▊                         | 10.6M/335M [00:00<00:10, 31.2MB/s]
# Downloading:   5%|█▎                        | 16.4M/335M [00:00<00:07, 41.0MB/s]
# Downloading:   7%|█▊                        | 22.9M/335M [00:00<00:06, 49.1MB/s]
# Downloading:   8%|██▏                       | 27.9M/335M [00:00<00:06, 47.8MB/s]
# Downloading:  10%|██▌                       | 33.1M/335M [00:00<00:06, 49.0MB/s]
# Downloading:  12%|███                       | 39.0M/335M [00:00<00:05, 52.0MB/s]
# Downloading:  13%|███▍                      | 44.5M/335M [00:01<00:05, 53.0MB/s]
# Downloading:  15%|███▊                      | 49.8M/335M [00:01<00:05, 52.2MB/s]
# Downloading:  16%|████▎                     | 55.0M/335M [00:01<00:05, 49.2MB/s]
# Downloading:  18%|████▋                     | 60.0M/335M [00:01<00:05, 49.1MB/s]
# Downloading:  20%|█████                     | 65.9M/335M [00:01<00:05, 51.9MB/s]
# Downloading:  21%|█████▌                    | 71.7M/335M [00:01<00:04, 53.8MB/s]
# Downloading:  23%|█████▉                    | 77.2M/335M [00:01<00:04, 53.9MB/s]
# Downloading:  25%|██████▍                   | 83.2M/335M [00:01<00:04, 56.0MB/s]
# Downloading:  27%|██████▉                   | 89.0M/335M [00:01<00:04, 56.5MB/s]
# Downloading:  29%|███████▍                  | 95.6M/335M [00:01<00:04, 59.1MB/s]
# Downloading:  30%|████████▏                  | 101M/335M [00:02<00:04, 58.2MB/s]
# Downloading:  32%|████████▋                  | 108M/335M [00:02<00:03, 59.8MB/s]
# Downloading:  34%|█████████▏                 | 114M/335M [00:02<00:03, 61.3MB/s]
# Downloading:  36%|█████████▋                 | 121M/335M [00:02<00:03, 61.4MB/s]
# Downloading:  38%|██████████▎                | 127M/335M [00:02<00:03, 62.8MB/s]
# Downloading:  40%|██████████▊                | 133M/335M [00:02<00:03, 61.9MB/s]
# Downloading:  42%|███████████▎               | 140M/335M [00:02<00:03, 61.0MB/s]
# Downloading:  44%|███████████▊               | 146M/335M [00:02<00:03, 53.4MB/s]
# Downloading:  45%|████████████▏              | 151M/335M [00:02<00:03, 52.2MB/s]
# Downloading:  47%|████████████▋              | 157M/335M [00:03<00:03, 47.9MB/s]
# Downloading:  48%|█████████████              | 162M/335M [00:03<00:03, 47.0MB/s]
# Downloading:  50%|█████████████▍             | 166M/335M [00:03<00:03, 42.5MB/s]
# Downloading:  51%|█████████████▊             | 171M/335M [00:03<00:04, 36.5MB/s]
# Downloading:  53%|██████████████▏            | 176M/335M [00:03<00:03, 40.2MB/s]
# Downloading:  54%|██████████████▌            | 180M/335M [00:03<00:03, 38.9MB/s]
# Downloading:  55%|██████████████▊            | 184M/335M [00:03<00:03, 38.7MB/s]
# Downloading:  56%|███████████████▏           | 188M/335M [00:03<00:04, 33.6MB/s]
# Downloading:  58%|███████████████▌           | 193M/335M [00:04<00:03, 37.5MB/s]
# Downloading:  59%|███████████████▉           | 197M/335M [00:04<00:03, 34.9MB/s]
# Downloading:  60%|████████████████▏          | 201M/335M [00:04<00:03, 34.0MB/s]
# Downloading:  61%|████████████████▍          | 204M/335M [00:04<00:03, 34.8MB/s]
# Downloading:  62%|████████████████▊          | 208M/335M [00:04<00:03, 34.5MB/s]
# Downloading:  63%|█████████████████          | 212M/335M [00:04<00:03, 36.0MB/s]
# Downloading:  64%|█████████████████▍         | 216M/335M [00:04<00:03, 36.0MB/s]
# Downloading:  66%|█████████████████▋         | 219M/335M [00:04<00:03, 35.3MB/s]
# Downloading:  67%|█████████████████▉         | 223M/335M [00:04<00:03, 35.6MB/s]
# Downloading:  68%|██████████████████▎        | 227M/335M [00:05<00:03, 34.6MB/s]
# Downloading:  69%|██████████████████▌        | 231M/335M [00:05<00:02, 36.3MB/s]
# Downloading:  70%|██████████████████▉        | 234M/335M [00:05<00:02, 35.9MB/s]
# Downloading:  71%|███████████████████▏       | 238M/335M [00:05<00:02, 35.8MB/s]
# Downloading:  72%|███████████████████▍       | 242M/335M [00:05<00:02, 36.1MB/s]
# Downloading:  73%|███████████████████▊       | 245M/335M [00:05<00:02, 36.0MB/s]
# Downloading:  74%|████████████████████       | 249M/335M [00:05<00:02, 35.4MB/s]
# Downloading:  75%|████████████████████▎      | 253M/335M [00:05<00:02, 35.9MB/s]
# Downloading:  77%|████████████████████▋      | 256M/335M [00:05<00:02, 35.9MB/s]
# Downloading:  78%|████████████████████▉      | 260M/335M [00:05<00:02, 35.6MB/s]
# Downloading:  79%|█████████████████████▎     | 264M/335M [00:06<00:01, 36.6MB/s]
# Downloading:  80%|█████████████████████▋     | 269M/335M [00:06<00:01, 40.3MB/s]
# Downloading:  81%|█████████████████████▉     | 273M/335M [00:06<00:01, 33.9MB/s]
# Downloading:  83%|██████████████████████▎    | 277M/335M [00:06<00:01, 37.3MB/s]
# Downloading:  84%|██████████████████████▋    | 281M/335M [00:06<00:01, 32.2MB/s]
# Downloading:  85%|███████████████████████    | 286M/335M [00:06<00:01, 36.1MB/s]
# Downloading:  87%|███████████████████████▍   | 291M/335M [00:06<00:01, 39.5MB/s]
# Downloading:  88%|███████████████████████▊   | 295M/335M [00:06<00:01, 34.7MB/s]
# Downloading:  89%|████████████████████████▏  | 299M/335M [00:07<00:00, 36.6MB/s]
# Downloading:  91%|████████████████████████▍  | 303M/335M [00:07<00:00, 33.2MB/s]
# Downloading:  92%|████████████████████████▊  | 308M/335M [00:07<00:00, 36.6MB/s]
# Downloading:  93%|█████████████████████████▏ | 312M/335M [00:07<00:00, 33.1MB/s]
# Downloading:  95%|█████████████████████████▌ | 316M/335M [00:07<00:00, 35.0MB/s]
# Downloading:  96%|█████████████████████████▉ | 321M/335M [00:07<00:00, 39.3MB/s]
# Downloading:  97%|██████████████████████████▎| 326M/335M [00:07<00:00, 35.9MB/s]
# Downloading:  98%|██████████████████████████▌| 329M/335M [00:07<00:00, 36.6MB/s]
# Downloading: 100%|███████████████████████████| 335M/335M [00:08<00:00, 41.8MB/s]
# Fetching 16 files: 100%|████████████████████████| 16/16 [02:45<00:00, 10.34s/it]
# Generating class images: 100%|██████████████████| 50/50 [08:28<00:00, 10.17s/it]
# Downloading: 100%|█████████████████████████| 1.06M/1.06M [00:00<00:00, 1.33MB/s]
# Downloading: 100%|████████████████████████████| 525k/525k [00:00<00:00, 832kB/s]
# Downloading: 100%|██████████████████████████████| 472/472 [00:00<00:00, 606kB/s]
# Downloading: 100%|█████████████████████████████| 806/806 [00:00<00:00, 2.50MB/s]
# Downloading: 100%|██████████████████████████████| 592/592 [00:00<00:00, 750kB/s]
# Downloading: 100%|███████████████████████████| 492M/492M [00:12<00:00, 39.7MB/s]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('vs/workbench/api/node/extensionHostProcess')}
#   warn(msg)
# /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//matplotlib_inline.backend_inline'), PosixPath('module')}
#   warn(msg)
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 120
# CUDA SETUP: Loading binary /home/alexander/anaconda3/envs/ds_py3.10/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda120.so...
# Caching latents: 100%|████████████████████████| 200/200 [00:29<00:00,  6.70it/s]
# Steps: 100%|███████████| 3200/3200 [23:29<00:00,  2.26it/s, loss=0.223, lr=5e-6]
# Fetching 16 files: 100%|█████████████████████| 16/16 [00:00<00:00, 22406.97it/s]
# Steps: 100%|███████████| 3200/3200 [23:34<00:00,  2.26it/s, loss=0.223, lr=5e-6]

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Download script
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/9db565e15e8e35f1ebb48e1409b8ddb129f6f1e9/scripts/convert_diffusers_to_original_stable_diffusion.py

# %%
#@markdown Run conversion.
ckpt_path = OUTPUT_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB), might loose some quality.
fp16 = False #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $OUTPUT_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at ./data/weights/frants/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
from IPython.display import display

model_path = OUTPUT_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16).to("cuda")
g_cuda = None

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 52362 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "photo of frants georgeclooney, anime style" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 50 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of sks guy, digital painting")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=50)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.

# %%
#@title (Optional) Delete diffuser weights and only keep the ckpt to free up drive space (4GB).

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
for f in glob(OUTPUT_DIR+"/*"):
    if not f.endswith(".ckpt"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)
